# %%
# Dependencies
import requests
import pandas as pd
import json
from pathlib import Path 
from attomapi import apikey
# for use with random delays
import time
import random

city_zips = {"Chicago": [60007, 60018, 60068, 60106, 60131, 60176, 60601, 60602, 60603, 60604, 60605, 60606, 60607, 60608, 60609, 60610, 60611, 60612, 60613, 60614, 60615, 60616, 60617, 60618, 60619, 60620, 60621, 60622, 60623, 60624, 60625, 60626, 60628, 60629, 60630, 60631, 60632, 60633, 60634, 60636, 60637, 60638, 60639, 60640, 60641, 60642, 60643, 60644, 60645, 60646, 60647, 60649, 60651, 60652, 60653, 60654, 60655, 60656, 60657, 60659, 60660, 60661, 60706, 60707, 60714, 60804, 60827], 
             "Denver": [80012, 80014, 80022, 80033, 80123, 80127, 80201, 80202, 80203, 80204, 80205, 80206, 80207, 80208, 80209, 80210, 80211, 80212, 80214, 80215, 80216, 80217, 80218, 80219, 80220, 80221, 80222, 80223, 80224, 80225, 80226, 80227, 80228, 80229, 80230, 80231, 80232, 80233, 80234, 80235, 80236, 80237, 80238, 80239, 80241, 80243, 80244, 80246, 80247, 80248, 80249, 80250, 80256, 80257, 80259, 80260, 80261, 80263, 80264, 80265, 80266, 80271, 80273, 80274, 80281, 80290, 80291, 80293, 80294, 80299], 
             "Memphis": [38103, 38104, 38105, 38106, 38107, 38108, 38109, 38111, 38112, 38117, 38125, 38126, 38127, 38128, 38133, 38134, 38135, 38138, 38139, 38141, 38017, 38002, 38016, 38018, 38028, 38066, 38060], 
             "New York": [10001, 10002, 10003, 10004, 10005, 10006, 10007, 10009, 10010, 10011, 10012, 10013, 10014, 10016, 10017, 10018, 10019, 10020, 10021, 10022, 10023, 10024, 10025, 10026, 10027, 10028, 10029, 10030, 10031, 10032, 10033, 10034, 10035, 10036, 10037, 10038, 10039, 10040, 10044, 10065, 10069, 10075, 10103, 10110, 10111, 10112, 10115, 10119, 10128, 10152, 10153, 10154, 10162, 10165, 10167, 10168, 10169, 10170, 10171, 10172, 10173, 10174, 10177, 10199, 10271, 10278, 10279, 10280, 10282, 10301, 10302, 10303, 10304, 10305, 10306, 10307, 10308, 10309, 10310, 10311, 10312, 10314, 10451, 10452, 10453, 10454, 10455, 10456, 10457, 10458, 10459, 10460, 10461, 10462, 10463, 10464, 10465, 10466, 10467, 10468, 10469, 10470, 10471, 10472, 10473, 10474, 10475, 11001, 11003, 11004, 11005, 11040, 11101, 11102, 11103, 11104, 11105, 11106, 11109, 11201, 11203, 11204, 11205, 11206, 11207, 11208, 11209, 11210, 11211, 11212, 11213, 11214, 11215, 11216, 11217, 11218, 11219, 11220, 11221, 11222, 11223, 11224, 11225, 11226, 11228, 11229, 11230, 11231, 11232, 11233, 11234, 11235, 11236, 11237, 11238, 11239, 11351, 11354, 11355, 11356, 11357, 11358, 11359, 11360, 11361, 11362, 11363, 11364, 11365, 11366, 11367, 11368, 11369, 11370, 11371, 11372, 11373, 11374, 11375, 11377, 11378, 11379, 11385, 11411, 11412, 11413, 11414, 11415, 11416, 11417, 11418, 11419, 11420, 11421, 11422, 11423, 11424, 11425, 11426, 11427, 11428, 11429, 11430, 11432, 11433, 11434, 11435, 11436, 11451, 11691, 11692, 11693, 11694, 11697], 
             "San Francisco": [94102, 94103, 94104, 94105, 94107, 94108, 94109, 94110, 94111, 94112, 94114, 94115, 94116, 94117, 94118, 94121, 94122, 94123, 94124, 94127, 94128, 94129, 94130, 94131, 94132, 94133, 94134, 94141, 94143, 94158, 94188]
            }

# %%
# Using delayed for loop to pull data within the free API usage requirements 
# this takes a while so save to file for use later

for city in city_zips:
    zips = city_zips[city]
    file = Path("resources/data_"+city+".txt")
    with open(file, 'w') as convert_file:
        convert_file.write(json.dumps(zips))
        for z in zips:
            conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode="+str(z)+"&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100&orderBy=saleAmt+desc", headers=headers)
            res = conn.getresponse()
            print(res)
            data = res.read()
            data_ny = json.loads(data.decode('utf-8'))
            convert_file.write(json.dumps(data_ny))
            # set random int 7-9 (in case they don't want automated...)
            r = random.randrange(7,10)
            # delay for the random time (s) frame
            time.sleep(r)
# Out:
# resources\data_Chicago.txt
# resources\data_Denver.txt
# resources\data_Memphis.txt
# resources\data_New York.txt
# resources\data_San Francisco.txt

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=73301&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100&orderBy=saleAmt+desc", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_301 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_301, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=73344&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_344 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_344, indent=4))

# %%
import http.client 
#trying something different
conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78613&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_613 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_613, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78617&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_617 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_617, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78652&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_652 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_652, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78653&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_653 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_653, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78660&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_660 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_660, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78701&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_701 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_701, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78702&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_702 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_702, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78703&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_703 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_703, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78704&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers)
res = conn.getresponse() 
data = res.read() 

data_704 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_704, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78705&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_705 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_705, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78708&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_708 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_708, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78709&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_709 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_709, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78710&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_710 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_710, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78711&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 
res = conn.getresponse() 
data = res.read() 

data_711 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_711, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78712&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_712 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_712, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78713&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_713 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_713, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78715&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_715 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_715, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78716&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_716 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_716, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78717&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_717 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_717, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78718&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_718 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_718, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78719&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_719 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_719, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78720&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_720 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_720, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78721&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_721 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_721, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78722&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_722 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_722, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78723&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_723 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_723, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78724&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_724 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_724, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78725&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_725 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_725, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78726&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_726 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_726, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78727&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_727 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_727, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78728&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_728 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_728, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78729&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_729 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_729, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78730&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_730 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_730, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78731&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_731 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_731, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78732&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_732 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_732, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78733&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_733 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_733, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78734&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_734 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_734, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78735&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_735 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_735, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78736&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_736 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_736, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78737&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_737 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_737, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78739&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_739 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_739, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78741&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_741 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_741, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78742&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_742 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_742, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78744&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_744 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_744, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78745&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_745 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_745, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78746&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_746 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_746, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78747&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_747 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_747, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78748&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_748 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_748, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78749&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_749 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_749, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78750&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_750 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_750, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78751&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_751 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_751, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78752&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_752 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_752, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78753&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_753 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_753, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78754&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_754 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_754, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78755&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_755 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_755, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78756&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_756 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_756, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78757&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_757 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_757, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78758&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_758 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_758, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78759&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_759 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_759, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78760&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_760 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_760, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78761&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_761 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_761, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78762&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_762 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_762, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78763&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_763 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_763, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78764&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_764 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_764, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78765&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_765 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_765, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78766&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_766 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_766, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78767&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_767 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_767, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78768&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_768 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_768, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78772&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_772 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_772, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78773&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_773 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_773, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78774&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_774 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_774, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78778&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_778 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_778, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78779&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_779 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_779, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78783&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_783 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_783, indent=4))

# %%
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "11003cf2f1787f8d42bfcf96177f9b43", 
    } 

conn.request("GET", "/propertyapi/v1.0.0/property/detail?postalcode=78799&minBeds=1&maxBeds=3&propertytype=RESIDENTIAL%20(NEC)&minuniversalsize=0&maxuniversalsize=1500&page=1&pagesize=100", headers=headers) 

res = conn.getresponse() 
data = res.read() 

data_799 = json.loads(data.decode('utf-8'))

# Pretty print the Python dictionary
print(json.dumps(data_799, indent=4))

# %%
# Convert the data to a DataFrame
propertydata = {
    #'Property type',
    #'Bedrooms',
    'Address' :data_dict["property"],
    #'City',
    #'State'
    }

# Convert the dictionary to a DataFrame
df = pd.DataFrame(propertydata)
df
